# %%
#https://universe.roboflow.com/roboflow-58fyf/rock-paper-scissors-sxsw/dataset/12
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AE4x6F2UzA8PofP1XkmV")
project = rf.workspace("roboflow-58fyf").project("rock-paper-scissors-sxsw")
version = project.version(12)
dataset = version.download("yolov8-obb")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Rock-Paper-Scissors-SXSW-12 in yolov8-obb:: 100%|██████████| 23784/23784 [00:08<00:00, 2773.06it/s]

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.7/107.7 GB disk)

# %%
# Train YOLOv8n on COCO8 for 10 epochs
# !yolo task= detect mode= train data=/content/Badges/data.yaml model=yolov8s.pt epochs=3 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from IPython.display import Image, display

# %%
display(Image(filename=f"/content/runs/detect/train14/results.png", width=1000))

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train14/weights/best.pt imgsz=640 conf=0.5 \
source=/content/Badges/test/images
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/12 /content/Badges/test/images/IMG-20240429-WA0025.jpg: 640x480 1 badge, 532.2ms
# image 2/12 /content/Badges/test/images/IMG-20240429-WA0026.jpg: 640x480 1 badge, 800.1ms
# image 3/12 /content/Badges/test/images/IMG-20240429-WA0027.jpg: 480x640 1 badge, 798.8ms
# image 4/12 /content/Badges/test/images/IMG-20240429-WA0028.jpg: 640x480 1 badge, 777.1ms
# image 5/12 /content/Badges/test/images/IMG-20240429-WA0037.jpg: 480x640 (no detections), 715.8ms
# image 6/12 /content/Badges/test/images/IMG-20240429-WA0038.jpg: 480x640 1 badge, 773.5ms
# image 7/12 /content/Badges/test/images/IMG-20240429-WA0039.jpg: 480x640 1 badge, 601.9ms
# image 8/12 /content/Badges/test/images/IMG-20240429-WA0040.jpg: 480x640 1 badge, 469.7ms
# image 9/12 /content/Badges/test/images/IMG-20240429-WA0049.jpg: 480x640 2 badges, 479.3ms
# ...

# %%
# Display inference on ALL test images
import glob
from IPython.display import Image, display
i = 0
for imageName in glob.glob("/content/runs/detect/predict3/*.jpg"): #assuming JPG

    print("\n")
    display(Image(filename=imageName))
    i = i +1
